# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# KASALI HANNAH MOTUNRAYO
# Data Scientist

# %% [markdown]
# I am intereted in data science because i love analyzing and drawing conclusions from data

# %% [markdown]
# ### My code ought to sum up numbers

# %%
5+6+1
# Out:
# 12

# %% [markdown]
# Horizontal rule,Numbered list,Hyperlinks,Images.
